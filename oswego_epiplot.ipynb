# %%
import pandas as pd

# %%
df = pd.read_clipboard()

# %%
df.head()
# Out:
#    ID  AGE SEX TIME OF MEAL ILL DATE OF ONSET TIME OF ONSET Choc ice cream  \
# 0   1   11   M        unk     N           NaN           NaN              N
# 1   2   52   F      8:00 PM   Y        19-Apr      12:30 AM              Y
# 2   3   65   M      6:30 PM   Y        19-Apr      12:30 AM              Y
# 3   4   59   F      6:30 PM   Y        19-Apr      12:30 AM              Y
# 4   5   13   F        unk     N           NaN           NaN              N
#
#   Fruit salad Van ice cream  ... Water Coffee Milk Brown bread Rolls Jello  \
# 0           N             N  ...     N      N    N           N     N     N
# 1           Y             Y  ...     N      Y    N           N     Y     N
# 2           Y             Y  ...     N      N    N           N     Y     N
# 3           Y             N  ...     N      N    N           N     Y     N
# 4           N             N  ...     N      N    N           N     N     N
#
#   Cabbage salad Mashed potatoes Spinach Baked ham
# ...

# %%
df.set_index('ID', inplace=True)

# %%
df.head()
# Out:
#     AGE SEX TIME OF MEAL ILL DATE OF ONSET TIME OF ONSET Choc ice cream  \
# ID
# 1    11   M        unk     N           NaN           NaN              N
# 2    52   F      8:00 PM   Y        19-Apr      12:30 AM              Y
# 3    65   M      6:30 PM   Y        19-Apr      12:30 AM              Y
# 4    59   F      6:30 PM   Y        19-Apr      12:30 AM              Y
# 5    13   F        unk     N           NaN           NaN              N
#
#    Fruit salad Van ice cream Cakes Water Coffee Milk Brown bread Rolls Jello  \
# ID
# 1            N             N     N     N      N    N           N     N     N
# 2            Y             Y     N     N      Y    N           N     Y     N
# 3            Y             Y     Y     N      N    N           N     Y     N
# 4            Y             N     N     N      N    N           N     Y     N
# 5            N             N     N     N      N    N           N     N     N
#
#    Cabbage salad Mashed potatoes Spinach Baked ham
# ID
# ...

# %%
cases_df = df.loc[df['ILL']=='Y']

# %%
controls_df = df.loc[df['ILL']=='N']

# %%
import seaborn as sns

# %%
sns.histplot(cases_df['DATE OF ONSET'])
# Out:
# <AxesSubplot: xlabel='DATE OF ONSET', ylabel='Count'>

# %%
cases_df['DATE TIME'] = cases_df['DATE OF ONSET'] + ' ' + cases_df['TIME OF ONSET']
# Out:
# C:\Users\ljens\AppData\Local\Temp\ipykernel_15688\1264899022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cases_df['DATE TIME'] = cases_df['DATE OF ONSET'] + ' ' + cases_df['TIME OF ONSET']

# %%
cases_df
# Out:
#     AGE SEX TIME OF MEAL ILL DATE OF ONSET TIME OF ONSET Choc ice cream  \
# ID
# 2    52   F      8:00 PM   Y        19-Apr      12:30 AM              Y
# 3    65   M      6:30 PM   Y        19-Apr      12:30 AM              Y
# 4    59   F      6:30 PM   Y        19-Apr      12:30 AM              Y
# 6    63   F      7:30 PM   Y        18-Apr      10:30 PM              Y
# 7    70   M      7:30 PM   Y        18-Apr      10:30 PM              Y
# 8    40   F      7:30 PM   Y        19-Apr       2:00 AM              N
# 9    15   F     10:00 PM   Y        19-Apr       1:00 AM              N
# 10   33   F      7:00 PM   Y        18-Apr      11:00 PM              Y
# 14   10   M      7:30 PM   Y        19-Apr       2:00 AM              N
# 16   32   F        unk     Y        19-Apr      10:30 AM              Y
# 17   62   F        unk     Y        19-Apr      12:30 AM              N
# 18   36   M        unk     Y        18-Apr      10:15 PM              Y
# ...

# %%
plt = sns.histplot(cases_df['DATE TIME'])

# %%
plt.ticklabel_format()

# %%
plt.set_xticklabels(plt.get_xticklabels(), rotation = 45)
# Out:
# C:\Users\ljens\AppData\Local\Temp\ipykernel_15688\2031578335.py:1: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.set_xticklabels(plt.get_xticklabels(), rotation = 45)
# [Text(0, 0, '19-Apr 12:30 AM'),
#  Text(1, 0, '18-Apr 10:30 PM'),
#  Text(2, 0, '19-Apr 2:00 AM'),
#  Text(3, 0, '19-Apr 1:00 AM'),
#  Text(4, 0, '18-Apr 11:00 PM'),
#  Text(5, 0, '19-Apr 10:30 AM'),
#  Text(6, 0, '18-Apr 10:15 PM'),
#  Text(7, 0, '18-Apr 10:00 PM'),
#  Text(8, 0, '18-Apr 9:45 PM'),
#  Text(9, 0, '18-Apr 9:00 PM'),
#  Text(10, 0, '18-Apr 9:15 PM'),
#  Text(11, 0, '18-Apr 11:30 PM'),
#  Text(12, 0, '18-Apr 9:30 PM'),
#  Text(13, 0, '19-Apr 2:30 AM'),
#  Text(14, 0, '18-Apr 3:00 PM'),
#  Text(15, 0, '19-Apr 12:00 AM*'),
#  Text(16, 0, '19-Apr 2:15 AM')]

# %%
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'

# %%
import matplotlib_inline

# %%
# %matplotlib inline 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'

# %%
p = sns.histplot(cases_df['DATE TIME'], )

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(12,5))
plt.hist(cases_df['DATE TIME'], )
plt.xlabel('DATE TIME')
plt.ylabel('Count')
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
cases_df['DATE TIME'].describe()
# Out:
# count                 46
# unique                17
# top       19-Apr 1:00 AM
# freq                  10
# Name: DATE TIME, dtype: object

# %%
cases_df.head()
# Out:
#     AGE SEX TIME OF MEAL ILL DATE OF ONSET TIME OF ONSET Choc ice cream  \
# ID
# 2    52   F      8:00 PM   Y        19-Apr      12:30 AM              Y
# 3    65   M      6:30 PM   Y        19-Apr      12:30 AM              Y
# 4    59   F      6:30 PM   Y        19-Apr      12:30 AM              Y
# 6    63   F      7:30 PM   Y        18-Apr      10:30 PM              Y
# 7    70   M      7:30 PM   Y        18-Apr      10:30 PM              Y
#
#    Fruit salad Van ice cream Cakes  ... Coffee Milk Brown bread Rolls Jello  \
# ID                                  ...
# 2            Y             Y     N  ...      Y    N           N     Y     N
# 3            Y             Y     Y  ...      N    N           N     Y     N
# 4            Y             N     N  ...      N    N           N     Y     N
# 6            Y             N     Y  ...      N    N           N     N     Y
# 7            Y             Y     N  ...      Y    Y           N     Y     Y
#
# ...

# %%
from datetime import datetime

# %%
d = '11-apr-1940'
dd = d.replace('apr','04')
o = datetime.strptime(dd, '%d-%m-%y %t')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 3
#       1 d = '11-apr-1940'
#       2 dd = d.replace('apr','04')
# ----> 3 o = datetime.strptime(dd, '%d-%m-%y %t')
#
# File c:\Users\ljens\anaconda3\envs\epi\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File c:\Users\ljens\anaconda3\envs\epi\lib\_strptime.py:341, in _strptime(data_string, format)
#     339         bad_directive = "%"
#     340     del err
# --> 341     raise ValueError("'%s' is a bad directive in format '%s'" %
# ...

# %%
dd
# Out:
# '11-04-1940'

# %%
cases_df['date'] = cases_df['DATE OF ONSET'].apply(lambda x: x.strip('-Apr'))
# Out:
# C:\Users\ljens\AppData\Local\Temp\ipykernel_15688\4003342157.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cases_df['date'] = cases_df['DATE OF ONSET'].apply(lambda x: x.strip('-Apr'))

# %%
cases_df['date'] = '1940-'+'04-' + cases_df['date']
# Out:
# C:\Users\ljens\AppData\Local\Temp\ipykernel_15688\809994823.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cases_df['date'] = '1940-'+'04-' + cases_df['date']

# %%
cases_df.head()
# Out:
#     AGE SEX TIME OF MEAL ILL DATE OF ONSET TIME OF ONSET Choc ice cream  \
# ID
# 2    52   F      8:00 PM   Y        19-Apr      12:30 AM              Y
# 3    65   M      6:30 PM   Y        19-Apr      12:30 AM              Y
# 4    59   F      6:30 PM   Y        19-Apr      12:30 AM              Y
# 6    63   F      7:30 PM   Y        18-Apr      10:30 PM              Y
# 7    70   M      7:30 PM   Y        18-Apr      10:30 PM              Y
#
#    Fruit salad Van ice cream Cakes  ... Rolls Jello Cabbage salad  \
# ID                                  ...
# 2            Y             Y     N  ...     Y     N             N
# 3            Y             Y     Y  ...     Y     N             N
# 4            Y             N     N  ...     Y     N             Y
# 6            Y             N     Y  ...     N     Y             N
# 7            Y             Y     N  ...     Y     Y             N
#
#    Mashed potatoes Spinach Baked ham        DATE TIME        date   time  \
# ID
# ...

# %%
convert24('12:30 AM')
# Out:
# '00:30'

# %%
def convert24(time):
    # Parse the time string into a datetime object
    t = datetime.strptime(time, '%I:%M %p')
    # Format the datetime object into a 24-hour time string
    return t.strftime('%H:%M')

# %%
cases_df['TIME OF ONSET'].apply(lambda x: convert24(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 cases_df['TIME OF ONSET'].apply(lambda x: convert24(x))
#
# File c:\Users\ljens\anaconda3\envs\epi\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\ljens\anaconda3\envs\epi\lib\site-packages\pandas\core\apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# -> 1105 return self.apply_standard()
#
# ...

# %%
cases_df['TIME OF ONSET'].describe()
# Out:
# count          46
# unique         17
# top       1:00 AM
# freq           10
# Name: TIME OF ONSET, dtype: object

# %%
cases_df['TIME OF ONSET'] = cases_df['TIME OF ONSET'].apply(lambda x: x.strip('*'))
# Out:
# C:\Users\ljens\AppData\Local\Temp\ipykernel_15688\2992258763.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cases_df['TIME OF ONSET'] = cases_df['TIME OF ONSET'].apply(lambda x: x.strip('*'))

# %%
cases_df['time'] = cases_df['TIME OF ONSET'].apply(lambda x: convert24(x))
# Out:
# C:\Users\ljens\AppData\Local\Temp\ipykernel_15688\239526421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cases_df['time'] = cases_df['TIME OF ONSET'].apply(lambda x: convert24(x))

# %%
cases_df['time']
# Out:
# ID
# 2     00:30
# 3     00:30
# 4     00:30
# 6     22:30
# 7     22:30
# 8     02:00
# 9     01:00
# 10    23:00
# 14    02:00
# 16    10:30
# 17    00:30
# 18    22:15
# 20    22:00
# 21    01:00
# 22    23:00
# 24    21:45
# 26    21:45
# 27    01:00
# 29    23:00
# 31    21:00
# 32    01:00
# 33    01:00
# 36    21:15
# 38    23:30
# 39    01:00
# 40    21:30
# 42    02:30
# 43    02:00
# 44    21:30
# 47    00:30
# 48    01:00
# 49    22:30
# 52    15:00
# 54    00:00
# 55    23:00
# 57    22:30
# 58    01:00
# 59    02:30
# 60    23:30
# 65    01:00
# 66    00:30
# 70    00:30
# 71    01:00
# 72    00:00
# 74    02:15
# 75    23:00
# Name: time, dtype: object

# %%
cases_df['datetime'] = cases_df['date'] + cases_df['time']
# Out:
# C:\Users\ljens\AppData\Local\Temp\ipykernel_15688\299568523.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cases_df['datetime'] = cases_df['date'] + cases_df['time']

# %%
cases_df['datetime'] = cases_df['datetime'].apply(lambda x: x.replace(':','')).astype('int')
# Out:
# C:\Users\ljens\AppData\Local\Temp\ipykernel_15688\1629514742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cases_df['datetime'] = cases_df['datetime'].apply(lambda x: x.replace(':','')).astype('int')

# %%
cases_df['datetime'].describe()
# Out:
# count           46
# unique          17
# top       19 01:00
# freq            10
# Name: datetime, dtype: object

# %%
sns.histplot(cases_df['datetime'], bins=17)
# Out:
# <AxesSubplot: xlabel='datetime', ylabel='Count'>

# %%
cases_df.head()
# Out:
#     AGE SEX TIME OF MEAL ILL DATE OF ONSET TIME OF ONSET Choc ice cream  \
# ID
# 2    52   F      8:00 PM   Y        19-Apr      12:30 AM              Y
# 3    65   M      6:30 PM   Y        19-Apr      12:30 AM              Y
# 4    59   F      6:30 PM   Y        19-Apr      12:30 AM              Y
# 6    63   F      7:30 PM   Y        18-Apr      10:30 PM              Y
# 7    70   M      7:30 PM   Y        18-Apr      10:30 PM              Y
#
#    Fruit salad Van ice cream Cakes  ... Rolls Jello Cabbage salad  \
# ID                                  ...
# 2            Y             Y     N  ...     Y     N             N
# 3            Y             Y     Y  ...     Y     N             N
# 4            Y             N     N  ...     Y     N             Y
# 6            Y             N     Y  ...     N     Y             N
# 7            Y             Y     N  ...     Y     Y             N
#
#    Mashed potatoes Spinach Baked ham        DATE TIME        date   time  \
# ID
# ...

# %%
from datetime import date

# %%
date.fromisoformat('04-18-1940 22:00')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 date.fromisoformat('04-18-1940 22:00')
#
# ValueError: Invalid isoformat string: '04-18-1940 22:00'

# %%
d = datetime(1940, 4, 19, 22, 30)

# %%
d.isoformat()
# Out:
# '1940-04-19T22:30:00'

# %%
cases_df['datetime'] = cases_df['date'] +'T'+ cases_df['time']
# Out:
# C:\Users\ljens\AppData\Local\Temp\ipykernel_15688\1879418741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cases_df['datetime'] = cases_df['date'] +'T'+ cases_df['time']

# %%
cases_df['datetime'].sort_values()
# Out:
# ID
# 52    1940-04-18T15:00
# 31    1940-04-18T21:00
# 36    1940-04-18T21:15
# 44    1940-04-18T21:30
# 40    1940-04-18T21:30
# 26    1940-04-18T21:45
# 24    1940-04-18T21:45
# 20    1940-04-18T22:00
# 18    1940-04-18T22:15
# 57    1940-04-18T22:30
# 6     1940-04-18T22:30
# 7     1940-04-18T22:30
# 49    1940-04-18T22:30
# 55    1940-04-18T23:00
# 29    1940-04-18T23:00
# 75    1940-04-18T23:00
# 10    1940-04-18T23:00
# 22    1940-04-18T23:00
# 38    1940-04-18T23:30
# 60    1940-04-18T23:30
# 72    1940-04-19T00:00
# 54    1940-04-19T00:00
# 2     1940-04-19T00:30
# 17    1940-04-19T00:30
# 70    1940-04-19T00:30
# 66    1940-04-19T00:30
# 3     1940-04-19T00:30
# 4     1940-04-19T00:30
# 47    1940-04-19T00:30
# 71    1940-04-19T01:00
# 65    1940-04-19T01:00
# 58    1940-04-19T01:00
# 21    1940-04-19T01:00
# 9     1940-04-19T01:00
# 39    1940-04-19T01:00
# 33    1940-04-19T01:00
# 32    1940-04-19T01:00
# 27    1940-04-19T01:00
# 48    1940-04-19T01:00
# ...

# %%
sns.histplot(cases_df['datetime'].sort_values())
# Out:
# <AxesSubplot: xlabel='datetime', ylabel='Count'>

# %%
fig = plt.figure(figsize=(12,5))
plt.hist(cases_df['datetime'].sort_values())
plt.xlabel('datetime')
plt.ylabel('Count')
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
cases_df['datetime'] = cases_df['datetime'].apply(lambda x: x.replace('T',' ')).sort_values()
# Out:
# C:\Users\ljens\AppData\Local\Temp\ipykernel_15688\736598905.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cases_df['datetime'] = cases_df['datetime'].apply(lambda x: x.replace('T',' ')).sort_values()

# %%
cases_df['datetime']
# Out:
# ID
# 2     1940-04-19 00:30
# 3     1940-04-19 00:30
# 4     1940-04-19 00:30
# 6     1940-04-18 22:30
# 7     1940-04-18 22:30
# 8     1940-04-19 02:00
# 9     1940-04-19 01:00
# 10    1940-04-18 23:00
# 14    1940-04-19 02:00
# 16    1940-04-19 10:30
# 17    1940-04-19 00:30
# 18    1940-04-18 22:15
# 20    1940-04-18 22:00
# 21    1940-04-19 01:00
# 22    1940-04-18 23:00
# 24    1940-04-18 21:45
# 26    1940-04-18 21:45
# 27    1940-04-19 01:00
# 29    1940-04-18 23:00
# 31    1940-04-18 21:00
# 32    1940-04-19 01:00
# 33    1940-04-19 01:00
# 36    1940-04-18 21:15
# 38    1940-04-18 23:30
# 39    1940-04-19 01:00
# 40    1940-04-18 21:30
# 42    1940-04-19 02:30
# 43    1940-04-19 02:00
# 44    1940-04-18 21:30
# 47    1940-04-19 00:30
# 48    1940-04-19 01:00
# 49    1940-04-18 22:30
# 52    1940-04-18 15:00
# 54    1940-04-19 00:00
# 55    1940-04-18 23:00
# 57    1940-04-18 22:30
# 58    1940-04-19 01:00
# 59    1940-04-19 02:30
# 60    1940-04-18 23:30
# ...

# %%
fig = plt.figure(figsize=(12,5))
plt.hist(cases_df['datetime'])
plt.xlabel('datetime')
plt.ylabel('Count')
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
cases_df.drop(columns = ['DATE OF ONSET','DATE TIME','datetime'], inplace=True)
# Out:
# C:\Users\ljens\AppData\Local\Temp\ipykernel_15688\2978643488.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cases_df.drop(columns = ['DATE OF ONSET','DATE TIME','datetime'], inplace=True)

# %%
cases_df['date'] = cases_df['date'].apply(lambda x: x.replace('1940-',''))
# Out:
# C:\Users\ljens\AppData\Local\Temp\ipykernel_15688\4270430945.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cases_df['date'] = cases_df['date'].apply(lambda x: x.replace('1940-',''))

# %%
cases_df['datetime'] = cases_df['date'] + ' ' + cases_df['time']
# Out:
# C:\Users\ljens\AppData\Local\Temp\ipykernel_15688\3505857170.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cases_df['datetime'] = cases_df['date'] + ' ' + cases_df['time']

# %%
cases_df.head()
# Out:
#     AGE SEX TIME OF MEAL ILL TIME OF ONSET Choc ice cream Fruit salad  \
# ID
# 2    52   F      8:00 PM   Y      12:30 AM              Y           Y
# 3    65   M      6:30 PM   Y      12:30 AM              Y           Y
# 4    59   F      6:30 PM   Y      12:30 AM              Y           Y
# 6    63   F      7:30 PM   Y      10:30 PM              Y           Y
# 7    70   M      7:30 PM   Y      10:30 PM              Y           Y
#
#    Van ice cream Cakes Water  ... Brown bread Rolls Jello Cabbage salad  \
# ID                            ...
# 2              Y     N     N  ...           N     Y     N             N
# 3              Y     Y     N  ...           N     Y     N             N
# 4              N     N     N  ...           N     Y     N             Y
# 6              N     Y     Y  ...           N     N     Y             N
# 7              Y     N     Y  ...           N     Y     Y             N
#
#    Mashed potatoes Spinach Baked ham   date   time     datetime
# ID
# ...

# %%
dt = cases_df['datetime'].sort_values()

# %%
dt
# Out:
# ID
# 52    04-18 15:00
# 31    04-18 21:00
# 36    04-18 21:15
# 44    04-18 21:30
# 40    04-18 21:30
# 26    04-18 21:45
# 24    04-18 21:45
# 20    04-18 22:00
# 18    04-18 22:15
# 57    04-18 22:30
# 6     04-18 22:30
# 7     04-18 22:30
# 49    04-18 22:30
# 55    04-18 23:00
# 29    04-18 23:00
# 75    04-18 23:00
# 10    04-18 23:00
# 22    04-18 23:00
# 38    04-18 23:30
# 60    04-18 23:30
# 72    04-19 00:00
# 54    04-19 00:00
# 2     04-19 00:30
# 17    04-19 00:30
# 70    04-19 00:30
# 66    04-19 00:30
# 3     04-19 00:30
# 4     04-19 00:30
# 47    04-19 00:30
# 71    04-19 01:00
# 65    04-19 01:00
# 58    04-19 01:00
# 21    04-19 01:00
# 9     04-19 01:00
# 39    04-19 01:00
# 33    04-19 01:00
# 32    04-19 01:00
# 27    04-19 01:00
# 48    04-19 01:00
# 43    04-19 02:00
# 14    04-19 02:00
# 8     04-19 02:00
# 74    04-19 02:15
# 42    04-19 02:30
# 59    04-19 02:30
# 16    04-19 10:30
# Name: datetime, dtype: object

# %%
fig = plt.figure(figsize=(12,5))
plt.hist(dt)
plt.xlabel('datetime')
plt.ylabel('Count')
locs, labels = plt.xticks()
plt.setp(labels, rotation=45)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
