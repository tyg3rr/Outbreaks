# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib_inline

# %%
df = pd.read_excel('C:\\Users\\ljens\\projects\\Outbreaks\\NationalOutbreakPublicDataTool.xlsx')

# %%
df.head()
# Out:
#    Year  Month      State      Primary Mode                Etiology  \
# 0  2009      1  Minnesota  Person-to-person  Norovirus Genogroup II
# 1  2009      1  Minnesota              Food               Norovirus
# 2  2009      2  Minnesota  Person-to-person               Norovirus
# 3  2009      1  Minnesota  Person-to-person       Norovirus unknown
# 4  2009      1  Minnesota              Food               Norovirus
#
#   Serotype or Genotype Etiology Status                       Setting  \
# 0              unknown       Confirmed                   Hotel/motel
# 1                  NaN       Suspected  Restaurant - Sit-down dining
# 2                  NaN       Suspected                Other, specify
# 3                  NaN       Confirmed                    Restaurant
# 4                  NaN       Confirmed                           NaN
#
#    Illnesses  Hospitalizations  ...  Deaths  Info on Deaths  Food Vehicle  \
# ...

# %%
df = df.set_index(['State','Year','Month'])

# %%
df.head()
# Out:
#                           Primary Mode                Etiology  \
# State     Year Month
# Minnesota 2009 1      Person-to-person  Norovirus Genogroup II
#                1                  Food               Norovirus
#                2      Person-to-person               Norovirus
#                1      Person-to-person       Norovirus unknown
#                1                  Food               Norovirus
#
#                      Serotype or Genotype Etiology Status  \
# State     Year Month
# Minnesota 2009 1                  unknown       Confirmed
#                1                      NaN       Suspected
#                2                      NaN       Suspected
#                1                      NaN       Confirmed
#                1                      NaN       Confirmed
#
#                                            Setting  Illnesses  \
# State     Year Month
# Minnesota 2009 1                       Hotel/motel         21
# ...

# %%
df.reset_index().loc[(df.reset_index()['State']=='Michigan') & (df.reset_index()['Primary Mode']=='Water'),:]
# Out:
#           State  Year  Month Primary Mode  \
# 2650   Michigan  2010      6        Water
# 3904   Michigan  2010      7        Water
# 6010   Michigan  2009      3        Water
# 6012   Michigan  2009      4        Water
# 6013   Michigan  2009      6        Water
# ...         ...   ...    ...          ...
# 55150  Michigan  2008      4        Water
# 55151  Michigan  2008      5        Water
# 55152  Michigan  2008      8        Water
# 55153  Michigan  2008      8        Water
# 57347  Michigan  2020      7        Water
#
#                                              Etiology  \
# 2650                             Campylobacter jejuni
# 3904   Legionella pneumophila; Legionella pneumophila
# 6010                                         Chlorine
# 6012                                         Chlorine
# 6013                                     Chlorine Gas
# ...                                               ...
# 55150                        Unknown - Chemical/Toxin
# ...

# %%
g = sns.histplot(df.reset_index().loc[(df.reset_index()['State']=='Michigan') & (df.reset_index()['Primary Mode']=='Water'),:]['Year'], bins=53)

# %%
df.reset_index().loc[(df.reset_index()['State']=='Michigan') & (df.reset_index()['Primary Mode']=='Water'),:]['Setting'].describe()
# Out:
# count                        63
# unique                       22
# top       Hotel/Motel/Lodge/Inn
# freq                         19
# Name: Setting, dtype: object

# %%
df.reset_index().loc[(df.reset_index()['State']=='Michigan') & (df.reset_index()['Primary Mode']=='Water'),:]['Year'].loc[df.reset_index().loc[(df.reset_index()['State']=='Michigan') & (df.reset_index()['Primary Mode']=='Water'),:]['Year']<2000]
# Out:
# 55132    1977
# 55133    1979
# 55134    1979
# 55135    1980
# 55136    1980
# 55137    1982
# 55138    1982
# 55139    1985
# 55140    1987
# 55141    1989
# 55142    1991
# 55143    1991
# Name: Year, dtype: int64

# %%
df.head()
# Out:
#                           Primary Mode                Etiology  \
# State     Year Month
# Minnesota 2009 1      Person-to-person  Norovirus Genogroup II
#                1                  Food               Norovirus
#                2      Person-to-person               Norovirus
#                1      Person-to-person       Norovirus unknown
#                1                  Food               Norovirus
#
#                      Serotype or Genotype Etiology Status  \
# State     Year Month
# Minnesota 2009 1                  unknown       Confirmed
#                1                      NaN       Suspected
#                2                      NaN       Suspected
#                1                      NaN       Confirmed
#                1                      NaN       Confirmed
#
#                                            Setting  Illnesses  \
# State     Year Month
# Minnesota 2009 1                       Hotel/motel         21
# ...
